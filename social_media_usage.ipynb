# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("social_media_usage.csv")

# %%
df
# Out:
#     User_ID        App  Daily_Minutes_Spent  Posts_Per_Day  Likes_Per_Day  \
# 0       U_1  Pinterest                  288             16             94
# 1       U_2   Facebook                  192             14            117
# 2       U_3  Instagram                  351             13            120
# 3       U_4     TikTok                   21             20            117
# 4       U_5   LinkedIn                  241             16              9
# ..      ...        ...                  ...            ...            ...
# 995   U_996   LinkedIn                  479              4             72
# 996   U_997  Instagram                  499             14            110
# 997   U_998   Facebook                  318              6            105
# 998   U_999     TikTok                  305             15            151
# 999  U_1000  Pinterest                  115             17             81
#
#      Follows_Per_Day
# 0                  0
# 1                 15
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   User_ID              1000 non-null   object
#  1   App                  1000 non-null   object
#  2   Daily_Minutes_Spent  1000 non-null   int64
#  3   Posts_Per_Day        1000 non-null   int64
#  4   Likes_Per_Day        1000 non-null   int64
#  5   Follows_Per_Day      1000 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 47.0+ KB

# %%
df.describe()
# Out:
#        Daily_Minutes_Spent  Posts_Per_Day  Likes_Per_Day  Follows_Per_Day
# count          1000.000000    1000.000000    1000.000000      1000.000000
# mean            247.368000      10.269000      94.682000        24.698000
# std             146.371921       6.121774      57.560943        14.842948
# min               5.000000       0.000000       0.000000         0.000000
# 25%             112.750000       5.000000      44.750000        12.000000
# 50%             246.000000      10.000000      94.000000        24.000000
# 75%             380.500000      16.000000     142.000000        38.000000
# max             500.000000      20.000000     200.000000        50.000000

# %%
df.isnull().sum()
# Out:
# User_ID                0
# App                    0
# Daily_Minutes_Spent    0
# Posts_Per_Day          0
# Likes_Per_Day          0
# Follows_Per_Day        0
# dtype: int64

# %%
df["User_ID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
# Easy Level Questions (8 Questions)

# %%
# Ques 1: What is the average time spent daily by users across all platforms?

# %%
# Ans 1:
df["Daily_Minutes_Spent"].mean()
# Out:
# np.float64(247.368)

# %%
# Ques 2: How many unique platforms are represented in the dataset?

# %%
# Ans 2:
df["App"].nunique()
# Out:
# 7

# %%
df["App"].unique()
# Out:
# array(['Pinterest', 'Facebook', 'Instagram', 'TikTok', 'LinkedIn',
#        'Twitter', 'Snapchat'], dtype=object)

# %%
# Ques 3: What is the total number of posts per day across all users?

# %%
# Ans 3:
df["Posts_Per_Day"].sum()
# Out:
# np.int64(10269)

# %%
# Ques 4: What is the average number of likes users give per day on each platform?

# %%
# Ans 4:
df.groupby("App").agg("Likes_Per_Day").mean()
# Out:
# App
# Facebook     99.301471
# Instagram    98.992857
# LinkedIn     97.081633
# Pinterest    92.114286
# Snapchat     93.820513
# TikTok       91.411348
# Twitter      90.185714
# Name: Likes_Per_Day, dtype: float64

# %%
df.groupby("App")["Likes_Per_Day"].mean()
# Out:
# App
# Facebook     99.301471
# Instagram    98.992857
# LinkedIn     97.081633
# Pinterest    92.114286
# Snapchat     93.820513
# TikTok       91.411348
# Twitter      90.185714
# Name: Likes_Per_Day, dtype: float64

# %%
# Ques 5: Which platform has the highest average number of follows per day?

# %%
# Ans 5:
df.groupby("App").agg("Follows_Per_Day").mean().sort_values()
# Out:
# App
# Facebook     23.117647
# Twitter      23.928571
# TikTok       24.439716
# Pinterest    24.792857
# LinkedIn     25.081633
# Snapchat     25.506410
# Instagram    25.864286
# Name: Follows_Per_Day, dtype: float64

# %%
# Ques 6: Find the minimum and maximum values for the daily minutes spent across users.

# %%
# Ans 6:
df["Daily_Minutes_Spent"].min()
# Out:
# np.int64(5)

# %%
df["Daily_Minutes_Spent"].max()
# Out:
# np.int64(500)

# %%
# Ques 7: How many users use Instagram?

# %%
# Ans 7:
df[df["App"] == "Instagram"]
# Out:
#     User_ID        App  Daily_Minutes_Spent  Posts_Per_Day  Likes_Per_Day  \
# 2       U_3  Instagram                  351             13            120
# 13     U_14  Instagram                  427              0            110
# 24     U_25  Instagram                  280             13             42
# 65     U_66  Instagram                  407             13            192
# 69     U_70  Instagram                   36             20            134
# ..      ...        ...                  ...            ...            ...
# 972   U_973  Instagram                  293              0            167
# 975   U_976  Instagram                  423             16             74
# 980   U_981  Instagram                  311             14            102
# 986   U_987  Instagram                  495             12            136
# 996   U_997  Instagram                  499             14            110
#
#      Follows_Per_Day
# 2                 48
# 13                19
# ...

# %%
# Ques 8: Find the total number of follows per day across all users.

# %%
# Ans 8: 
df["Follows_Per_Day"].sum()
# Out:
# np.int64(24698)

# %%
# Medium Level Questions (8 Questions)

# %%
# Ques 9: What is the average time spent on each platform, and how does it compare across platforms?

# %%
# Ans 9:
df.head(2)
# Out:
#   User_ID        App  Daily_Minutes_Spent  Posts_Per_Day  Likes_Per_Day  \
# 0     U_1  Pinterest                  288             16             94
# 1     U_2   Facebook                  192             14            117
#
#    Follows_Per_Day
# 0                0
# 1               15

# %%
df.groupby("App").agg("Daily_Minutes_Spent").mean().sort_values()
# Out:
# App
# TikTok       233.418440
# LinkedIn     236.054422
# Pinterest    236.207143
# Facebook     247.169118
# Snapchat     256.551282
# Twitter      257.685714
# Instagram    264.100000
# Name: Daily_Minutes_Spent, dtype: float64

# %%
plt.figure(figsize= (6,5))
plt.title("Average Time Spend(in min)")
ax = sns.barplot(df.groupby("App").agg("Daily_Minutes_Spent").mean().sort_values())
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '233.418'),
#  Text(0, 0, '236.054'),
#  Text(0, 0, '236.207'),
#  Text(0, 0, '247.169'),
#  Text(0, 0, '256.551'),
#  Text(0, 0, '257.686'),
#  Text(0, 0, '264.1')]

# %%
# Ques 10: Identify the platform with the highest average posts per day.

# %%
# Ans 10:
df.groupby("App").agg("Posts_Per_Day").mean().sort_values()
# Out:
# App
# Facebook      9.522059
# TikTok        9.560284
# Snapchat     10.000000
# LinkedIn     10.176871
# Pinterest    10.628571
# Twitter      10.685714
# Instagram    11.328571
# Name: Posts_Per_Day, dtype: float64

# %%
# Ques 11: Calculate the standard deviation of daily minutes spent for each platform.

# %%
# Ans 11:
df.groupby("App").agg("Daily_Minutes_Spent").std().sort_values()
# Out:
# App
# LinkedIn     137.069864
# Pinterest    145.312637
# TikTok       145.421120
# Snapchat     145.545660
# Twitter      146.683729
# Instagram    151.064201
# Facebook     153.655630
# Name: Daily_Minutes_Spent, dtype: float64

# %%
plt.figure(figsize= (6,5))
plt.title("Standard Deviation of Time Spend(in min)")
ax = sns.barplot(df.groupby("App").agg("Daily_Minutes_Spent").std().sort_values())
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '137.07'),
#  Text(0, 0, '145.313'),
#  Text(0, 0, '145.421'),
#  Text(0, 0, '145.546'),
#  Text(0, 0, '146.684'),
#  Text(0, 0, '151.064'),
#  Text(0, 0, '153.656')]

# %%
# Ques 12: How does the average daily posts vary with the average daily likes?

# %%
# Ans 12:

# %%
# Ques 13: Find the correlation between daily minutes spent and posts per day.

# %%
# Ans 13:

# %%
# Ques 14: What is the most common number of follows per day across the dataset?

# %%
# Ans 14: 
df["Follows_Per_Day"].value_counts()
# Out:
# Follows_Per_Day
# 47    30
# 20    29
# 9     27
# 15    25
# 2     24
# 22    24
# 12    23
# 39    23
# 10    23
# 4     23
# 42    23
# 16    22
# 0     22
# 5     22
# 43    22
# 35    21
# 45    21
# 30    21
# 21    20
# 37    20
# 23    20
# 8     20
# 25    20
# 32    20
# 34    20
# 44    19
# 7     19
# 17    19
# 33    19
# 38    18
# 49    18
# 41    18
# 26    18
# 28    18
# 19    18
# 24    18
# 14    18
# 3     18
# 18    17
# 40    17
# 50    17
# 46    16
# 48    16
# 1     16
# 11    15
# 36    15
# 27    15
# 6     15
# 13    14
# 31    13
# 29    11
# Name: count, dtype: int64

# %%
# Ques 15: How many users spend more than 2 hours on their platforms daily?

# %%
# Ans 15:
df[df["Daily_Minutes_Spent"] > 120]
# Out:
#     User_ID        App  Daily_Minutes_Spent  Posts_Per_Day  Likes_Per_Day  \
# 0       U_1  Pinterest                  288             16             94
# 1       U_2   Facebook                  192             14            117
# 2       U_3  Instagram                  351             13            120
# 4       U_5   LinkedIn                  241             16              9
# 5       U_6    Twitter                  464              3            137
# ..      ...        ...                  ...            ...            ...
# 994   U_995    Twitter                  464              2            149
# 995   U_996   LinkedIn                  479              4             72
# 996   U_997  Instagram                  499             14            110
# 997   U_998   Facebook                  318              6            105
# 998   U_999     TikTok                  305             15            151
#
#      Follows_Per_Day
# 0                  0
# 1                 15
# ...

# %%
# Ques 16: Create a distribution plot showing daily minutes spent across platforms.

# %%
# Ans 16: 
sns.histplot(x = "Daily_Minutes_Spent", data = df)
# Out:
# <Axes: xlabel='Daily_Minutes_Spent', ylabel='Count'>

# %%
# Hard Questions

# %%
# Ques 17: Perform a time analysis to find the top 3 platforms where users spend the most time daily.

# %%
# Ans 17: 
df.groupby("App").agg("Daily_Minutes_Spent").mean().sort_values()
# Out:
# App
# TikTok       233.418440
# LinkedIn     236.054422
# Pinterest    236.207143
# Facebook     247.169118
# Snapchat     256.551282
# Twitter      257.685714
# Instagram    264.100000
# Name: Daily_Minutes_Spent, dtype: float64

# %%
# Ques 18: Analyze whether users with high daily minutes spent also have higher posts per day.
# Out:
# Index(['User_ID', 'App', 'Daily_Minutes_Spent', 'Posts_Per_Day',
#        'Likes_Per_Day', 'Follows_Per_Day'],
#       dtype='object')

# %%
# Ans 18: 
correlation = df['Daily_Minutes_Spent'].corr(df['Posts_Per_Day'])

print("Correlation between daily minutes spent and posts per day:")
print(correlation)

plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Daily_Minutes_Spent', y='Posts_Per_Day', alpha = 0.6)
plt.title('Relationship between Daily Minutes Spent and Posts Per Day')
plt.xlabel('Daily Minutes Spent')
plt.ylabel('Posts Per Day')
plt.show()
# Out:
# Correlation between daily minutes spent and posts per day:
# -0.023967780205297343

# %%
bins = [0, 30, 60, 90, 120, 150, 180, df['Daily_Minutes_Spent'].max()]
labels = ['0-30', '30-60', '60-90', '90-120', '120-150', '150-180', '180+']
df['Time_Bins'] = pd.cut(df['Daily_Minutes_Spent'], bins=bins, labels=labels)

avg_posts_per_bin = df.groupby('Time_Bins')['Posts_Per_Day'].mean()

plt.figure(figsize=(10, 6))
avg_posts_per_bin.plot(kind='line', marker='o', color='b')
plt.title('Average Posts Per Day vs. Daily Minutes Spent')
plt.xlabel('Daily Minutes Spent (Binned)')
plt.ylabel('Average Posts Per Day')
plt.grid(True)
plt.show()
# Out:
# /var/folders/dg/gr067x097c1f6n38wpwrcsr80000gn/T/ipykernel_21855/3418191841.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_posts_per_bin = df.groupby('Time_Bins')['Posts_Per_Day'].mean()

# %%
df["Time_Bins"]
# Out:
# 0        180+
# 1        180+
# 2        180+
# 3        0-30
# 4        180+
#         ...
# 995      180+
# 996      180+
# 997      180+
# 998      180+
# 999    90-120
# Name: Time_Bins, Length: 1000, dtype: category
# Categories (7, object): ['0-30' < '30-60' < '60-90' < '90-120' < '120-150' < '150-180' < '180+']

# %%
# Ques 19: Find and visualize the correlation between daily minutes spent, posts, likes, and follows.

# %%
# Ans 19:
columns_of_interest = ['Daily_Minutes_Spent', 'Posts_Per_Day', 'Likes_Per_Day', 'Follows_Per_Day']
correlation_matrix = df[columns_of_interest].corr()

# Plot the heatmap to visualize the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of User Engagement Metrics')
plt.show()

# %%
# Ques 20: Conduct a comparative analysis of posts and likes to see if higher posts correlate with higher likes across platforms.

# %%
df.describe()
# Out:
#        Daily_Minutes_Spent  Posts_Per_Day  Likes_Per_Day  Follows_Per_Day
# count          1000.000000    1000.000000    1000.000000      1000.000000
# mean            247.368000      10.269000      94.682000        24.698000
# std             146.371921       6.121774      57.560943        14.842948
# min               5.000000       0.000000       0.000000         0.000000
# 25%             112.750000       5.000000      44.750000        12.000000
# 50%             246.000000      10.000000      94.000000        24.000000
# 75%             380.500000      16.000000     142.000000        38.000000
# max             500.000000      20.000000     200.000000        50.000000

# %%
# Ans 20:
def post_cat(value):
    if (value <= 4):
        return("0-4")
    elif (4 < value <= 8):
        return("5-8")
    elif (8 < value <= 12):
        return("9-12")
    elif (12 < value <= 16):
        return("13-16")
    elif (16 < value <= 20):
        return("17-20")

df["sorted_posts_pd"] = df["Posts_Per_Day"].apply(post_cat)

# %%
category_order = ['0-4', '5-8', '9-12', '13-16', '17-20']

df['sorted_posts_pd'] = pd.Categorical(df['sorted_posts_pd'], categories=category_order, ordered=True)

# %%
relation = df.groupby("sorted_posts_pd").agg("Likes_Per_Day").mean().sort_index()
# Out:
# /var/folders/dg/gr067x097c1f6n38wpwrcsr80000gn/T/ipykernel_21855/2755610025.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   relation = df.groupby("sorted_posts_pd").agg("Likes_Per_Day").mean().sort_index()

# %%
sns.lineplot(relation, marker="o")
# Out:
# <Axes: xlabel='sorted_posts_pd', ylabel='Likes_Per_Day'>

# %%
# Ques 21: Group users by platform and analyze trends in daily follows relative to posts and likes per day.

# %%
# Ans 21:

platform_trends = df.groupby('App')[['Posts_Per_Day', 'Likes_Per_Day', 'Follows_Per_Day']].mean()
plt.figure(figsize=(12, 8))
sns.lineplot(platform_trends, markers=True)
plt.title("Trends in Daily Posts, Likes, and Follows by Platform")
plt.xlabel("Platform")
plt.ylabel("Average Daily Counts")
plt.grid(True)
